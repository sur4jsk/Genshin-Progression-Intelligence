# %%
import pandas as pd

file_path = "../data/raw/genshin.xlsx"
df = pd.read_excel(file_path)

df.head()

# %%
print("Rows, Columns:", df.shape)

# %%
df.columns

# %%
df.info()

# %%
df.isnull().sum().sort_values(ascending=False)

# %%
df.duplicated().sum()

# %%
df["name"].duplicated().sum()

# %%
print("Unique Regions:", df["region"].nunique())
print(df["region"].unique())

print("Unique Visions:", df["vision"].nunique())
print(df["vision"].unique())

print("Unique Weapon Types:", df["weapon_type"].nunique())
print(df["weapon_type"].unique())

# %%
df.describe()

# %%
df["release_date"].head(10)

# %%
df["rarity"].value_counts()
